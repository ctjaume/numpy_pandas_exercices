# %% [markdown]
# ### Ejercicios de Pandas
#
# Para la parte de Pandas usaremos el mismo conjunto de datos de música de Spotify, en concreto tendremos un conjunto de datos de canciones de varios artistas en el mundo y para cada canción está presente:
#
#     Varias estadísticas de la versión musical en spotify, incluido el número de streams;
#     Número de visualizaciones del vídeo musical oficial de la canción en youtube
#
# Las variables que tendremos en este dataframe son:
# Incluye 26 variables para cada una de las canciones recogidas de spotify. Estas variables se describen brevemente a continuación:
#
#     -Track: nombre de la canción, tal y como aparece en la plataforma Spotify.
#
#     -Artist: nombre del artista.
#
#     -Url_spotify: Url de la canción.
#
#     -Album: el álbum en el que se encuentra la canción en Spotify.
#
#     -Album_type: indica si la canción se publica en Spotify como single o dentro de un álbum.
#
#     -Uri: un enlace de Spotify utilizado para encontrar la canción a través de la API.
#
#     -Danceability: describe lo adecuada que es una canción para bailar basándose en una combinación de elementos musicales como el tempo, la estabilidad del ritmo, la fuerza del compás y la regularidad general. Un valor de 0,0 es el menos bailable y 1,0 el más bailable.
#
#     -Energy: es una medida de 0,0 a 1,0 y representa una medida perceptiva de intensidad y actividad. Normalmente, las pistas energéticas son rápidas, ruidosas y ruidosas. Por ejemplo, el death metal tiene mucha energía, mientras que un preludio de Bach tiene una puntuación baja en la escala. Las características perceptivas que contribuyen a este atributo incluyen el rango dinámico, el volumen percibido, el timbre, la velocidad de inicio y la entropía general.
#
#     -Key: la clave de la pista. Los números enteros se asignan a los tonos utilizando la notación estándar Pitch Class. Por ejemplo, 0 = C, 1 = C♯/D♭, 2 = D, y así sucesivamente. Si no se detecta ninguna tonalidad, el valor es -1.
#
#     -Loudness: la sonoridad global de una pista en decibelios (dB). Los valores de sonoridad se promedian en toda la pista y son útiles para comparar la sonoridad relativa de las pistas. La sonoridad es la cualidad de un sonido que es el principal correlato psicológico de la fuerza física (amplitud). Los valores suelen oscilar entre -60 y 0 db.
#
#     -Speechiness: detecta la presencia de palabras habladas en una pista. Cuanto más exclusivamente hablada sea la grabación (por ejemplo, un programa de entrevistas, un audiolibro, poesía), más se acercará a 1,0 el valor del atributo. Los valores superiores a 0,66 describen pistas que probablemente estén compuestas en su totalidad por palabras habladas. Los valores entre 0,33 y 0,66 describen pistas que pueden contener tanto música como voz, ya sea en secciones o en capas, incluyendo casos como la música rap. Los valores por debajo de 0,33 representan probablemente música y otras pistas no habladas.
#
#     -Acousticness: una medida de confianza de 0,0 a 1,0 para determinar si la pista es acústica. 1,0 representa una confianza alta en que la pista es acústica.
#
#     -Instrumentalness: predice si una pista no contiene voces. Los sonidos "ooh" y "aah" se consideran instrumentales en este contexto. Las pistas de rap o spoken word son claramente "vocales". Cuanto más se acerque el valor de instrumental a 1,0, mayor será la probabilidad de que la canción no contenga voces. Los valores superiores a 0,5 representan pistas instrumentales, pero la confianza es mayor a medida que el valor se acerca a 1,0.
#
#     -Liveness: detecta la presencia de público en la grabación. Los valores más altos representan una mayor probabilidad de que la pista se haya interpretado en directo. Un valor superior a 0,8 proporciona una gran probabilidad de que la pista sea en directo.
#
#     -Valence: una medida de 0,0 a 1,0 que describe la positividad musical que transmite una pista. Las pistas con una valencia alta suenan más positivas (por ejemplo, felices, alegres, eufóricas), mientras que las pistas con una valencia baja suenan más negativas (por ejemplo, tristes, deprimidas, enfadadas).
#
#     -Tempo: el tempo global estimado de una pista en pulsaciones por minuto (BPM). En terminología musical, el tempo es la velocidad o el ritmo de una pieza determinada y se deriva directamente de la duración media de los tiempos.
#
#     -Duration_ms: duración de la pista en milisegundos.
#
#     -Stream: número de streams de la canción en Spotify.
#
#     -Url_youtube: url del vídeo enlazado a la canción en Youtube, si lo tiene.
#
#     -Title: título del videoclip en Youtube.
#
#     -Channel: nombre del canal que ha publicado el vídeo.
#
#     -Views: número de vistas.
#
#     -Likes: número de me gusta.
#
#     -Comments: número de comentarios.
#
#     -Description: descripción del vídeo en Youtube.
#
#     -Licensed: Indica si el vídeo representa contenido con licencia, lo que significa que el contenido fue subido a un canal vinculado a un socio de contenido de Youtube y luego reclamado por dicho socio.
#
#     -official_video: valor booleano que indica si el vídeo encontrado es el vídeo oficial de la canción.
#
#
# Los ejercicios que os plantemos para esta parte de la evaluación son:
#
# 1.Importad Pandas

# %%
import pandas as pd
import numpy as np
import regex as re
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2.Exploración del conjunto de datos:
#
#     Cargad el fichero, al cargarlo os aparecerá una columna llamada "Unnamed: 0". Cargad el dataset sin que aparezca esta columna.

# %%
#Indicamos que la primera columna sea el índice

df1 = pd.read_csv('../datos/Spotify_Youtube.csv', index_col=0)
df1.head()
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                  Plastic Beach      album
# 4                                       Gorillaz      album
#
#                                     Uri Danceability Energy   Key Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT        0,818  0,705   6,0   -6,679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG        0,676  0,703   8,0   -5,815
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU        0,695  0,923   1,0    -3,93
# 3  spotify:track:0q6LuUqGLUiCPP1cbdwFs3        0,689  0,739   2,0    -5,81
# 4  spotify:track:7yMiX7n9SBvadzox8T5jzT        0,663  0,694  10,0   -8,627
#
#    ...                                  Url_youtube  \
# 0  ...  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1  ...  https://www.youtube.com/watch?v=yYDmaexVHic
# 2  ...  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3  ...  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4  ...  https://www.youtube.com/watch?v=1V_xRb0x9aw
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...  Gorillaz    8435055.0
# 3     Gorillaz - On Melancholy Hill (Official Video)  Gorillaz  211754952.0
# 4         Gorillaz - Clint Eastwood (Official Video)  Gorillaz  618480958.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3  1788577.0   55229.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 4  6197318.0  155930.0  The official music video for Gorillaz - Clint ...
#
#   Licensed Official_video        Stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08
# 2     True           True  6.306347e+07
# 3     True           True  4.346636e+08
# 4     True           True  6.172597e+08
#
# [5 rows x 27 columns]

# %% [markdown]
#
#     Además realizad un análisis exploratorio que incluya:
#
#         (Cuando leais el fichero, veremos que no podemos ver todas las columnas, utilizad el comando correcto para poder visualizarlas todas cuando hacemos un head)

# %%
pd.options.display.max_columns = None

# %% [markdown]
#         -Primeras 5 filas del dataframe
#         -Últimas 5 filas del dataframe
#         -10 filas aleatorias del dataframe

# %%
df1.head()
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                  Plastic Beach      album
# 4                                       Gorillaz      album
#
#                                     Uri Danceability Energy   Key Loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT        0,818  0,705   6,0   -6,679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG        0,676  0,703   8,0   -5,815
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU        0,695  0,923   1,0    -3,93
# 3  spotify:track:0q6LuUqGLUiCPP1cbdwFs3        0,689  0,739   2,0    -5,81
# 4  spotify:track:7yMiX7n9SBvadzox8T5jzT        0,663  0,694  10,0   -8,627
#
#   Speechiness Acousticness Instrumentalness  Liveness  Valence    Tempo  \
# 0       0,177      0,00836          0,00233    0.6130    0.772  138.559
# 1      0,0302       0,0869         0,000687    0.0463    0.852   92.761
# 2      0,0522       0,0425           0,0469    0.1160    0.551  108.014
# 3       0,026     1,51e-05            0,509    0.0640    0.578  120.423
# 4       0,171       0,0253              0,0    0.0698    0.525  167.953
#
#    Duration_ms                                  Url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
# 2     215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3     233867.0  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4     340920.0  https://www.youtube.com/watch?v=1V_xRb0x9aw
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...  Gorillaz    8435055.0
# 3     Gorillaz - On Melancholy Hill (Official Video)  Gorillaz  211754952.0
# 4         Gorillaz - Clint Eastwood (Official Video)  Gorillaz  618480958.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3  1788577.0   55229.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 4  6197318.0  155930.0  The official music video for Gorillaz - Clint ...
#
#   Licensed Official_video        Stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08
# 2     True           True  6.306347e+07
# 3     True           True  4.346636e+08
# 4     True           True  6.172597e+08

# %%
df1.tail()
# Out:
#             Artist                                        Url_spotify  \
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                 Track                           Album  \
# 20713            JUST DANCE HARDSTYLE            JUST DANCE HARDSTYLE
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SET FIRE TO THE RAIN HARDSTYLE
# 20715       OUTSIDE HARDSTYLE SPED UP       OUTSIDE HARDSTYLE SPED UP
# 20716             ONLY GIRL HARDSTYLE             ONLY GIRL HARDSTYLE
# 20717              MISS YOU HARDSTYLE              MISS YOU HARDSTYLE
#
#       Album_type                                   Uri Danceability Energy  \
# 20713     single  spotify:track:0RtcKQGyI4hr8FgFH1TuYG        0,582  0,926
# 20714     single  spotify:track:3rHvPA8lUnPBkaLyPOc0VV        0,531  0,936
# 20715     single  spotify:track:4jk00YxPtPbhvHJE9N4ddv        0,443   0,83
# 20716     single  spotify:track:5EyErbpsugWliX006eTDex        0,417  0,767
# 20717     single  spotify:track:6lOn0jz1QpjcWeXo1oMm0k        0,498  0,938
#
#        Key Loudness Speechiness Acousticness Instrumentalness  Liveness  \
# 20713  5,0   -6,344      0,0328        0,448              0,0    0.0839
# 20714  4,0   -1,786       0,137        0,028              0,0    0.0923
# 20715  4,0   -4,679      0,0647       0,0243              0,0    0.1540
# 20716  9,0   -4,004       0,419        0,356           0,0184    0.1080
# 20717  6,0   -4,543       0,107      0,00277            0,911    0.1360
#
#        Valence    Tempo  Duration_ms  \
# 20713   0.6580   90.002      94667.0
# 20714   0.6570  174.869     150857.0
# 20715   0.4190  168.388     136842.0
# 20716   0.5390  155.378     108387.0
# 20717   0.0787  160.067     181500.0
#
#                                        Url_youtube  \
# 20713  https://www.youtube.com/watch?v=5SHmKFKlNqI
# 20714  https://www.youtube.com/watch?v=ocTH6KxllDQ
# 20715  https://www.youtube.com/watch?v=5wFhE-HY0hg
# 20716  https://www.youtube.com/watch?v=VMFLbFRNCn0
# 20717  https://www.youtube.com/watch?v=zau0dckCFi0
#
#                                 Title              Channel     Views   Likes  \
# 20713            JUST DANCE HARDSTYLE  SICK LEGEND - Topic   71678.0  1113.0
# 20714  SET FIRE TO THE RAIN HARDSTYLE  SICK LEGEND - Topic  164741.0  2019.0
# 20715       OUTSIDE HARDSTYLE SPED UP  SICK LEGEND - Topic   35646.0   329.0
# 20716             ONLY GIRL HARDSTYLE  SICK LEGEND - Topic    6533.0    88.0
# 20717              MISS YOU HARDSTYLE  SICK LEGEND - Topic  158697.0  2484.0
#
#        Comments                                        Description Licensed  \
# 20713       0.0  Provided to YouTube by Routenote\n\nJUST DANCE...     True
# 20714       0.0  Provided to YouTube by Routenote\n\nSET FIRE T...     True
# 20715       0.0  Provided to YouTube by Routenote\n\nOUTSIDE HA...     True
# 20716       0.0  Provided to YouTube by Routenote\n\nONLY GIRL ...     True
# 20717       0.0  Provided to YouTube by Routenote\n\nMISS YOU H...     True
#
#       Official_video      Stream
# 20713           True   9227144.0
# 20714           True  10898176.0
# 20715           True   6226110.0
# 20716           True   6873961.0
# 20717           True   5695584.0

# %%
df1.sample(10)
# Out:
#                     Artist                                        Url_spotify  \
# 13717           Ryan Lewis  https://open.spotify.com/artist/4myTppRgh0rojL...
# 10389   Héctor "El Father"  https://open.spotify.com/artist/2TjgzYcbTdsZjb...
# 3321   Gilberto Santa Rosa  https://open.spotify.com/artist/27vNK840zYq6If...
# 7989             Rammstein  https://open.spotify.com/artist/6wWVKhxIU2cEi0...
# 18133       Shiloh Dynasty  https://open.spotify.com/artist/1wxPItEzr7U7rG...
# 10994              Cherish  https://open.spotify.com/artist/1c70yCa8sRgIiQ...
# 15859      The Paper Kites  https://open.spotify.com/artist/79hrYiudVcFyyx...
# 9887              Dina Rae  https://open.spotify.com/artist/5jNmxPYz8QE5rY...
# 1058               MF DOOM  https://open.spotify.com/artist/2pAWfrd7WFF3Xh...
# 6938          Banda Machos  https://open.spotify.com/artist/7MyUjj79oHy7I8...
#
#                                             Track  \
# 13717                           Irish Celebration
# 10389                                      Sacala
# 3321                                  Sombra Loca
# 7989                                      Du hast
# 18133                             Losing Interest
# 10994                              Moment In Time
# 15859                                       Paint
# 9887   GET LIT (DEDICATION) הקדשה [feat. PA. Dre]
# 1058      Rapp Snitch Knishes feat. Mr. Fantastik
# 6938                                Leña de pirul
#
#                                             Album Album_type  \
# 13717                           Irish Celebration     single
# 10389                                      Sacala     single
# 3321                                    Auténtico      album
# 7989                                    Sehnsucht      album
# 18133                             Losing Interest     single
# 10994                               Unappreciated      album
# 15859                                 Young North     single
# 9887   GET LIT (DEDICATION) הקדשה [feat. PA. Dre]     single
# 1058                                    MM...FOOD      album
# 6938               La reina de las bandas Vol. II      album
#
#                                         Uri Danceability Energy   Key  \
# 13717  spotify:track:2rLcR01HB0ScBAsgxX4Z62        0,367  0,847   2,0
# 10389  spotify:track:2A4S6qvdOXOl0IvGasvpi5        0,616  0,655   1,0
# 3321   spotify:track:7hqI73OXybfZ6FV9O4WrNs        0,761  0,686   0,0
# 7989   spotify:track:6uEvFCaOqXyEidoO8BZbyh         0,64  0,922   9,0
# 18133  spotify:track:3RbNcjVnQixKa1sULcwd2K         0,96   0,36  10,0
# 10994  spotify:track:5JSa4nDr8l9CSmzDC5Qo8W        0,608  0,326   2,0
# 15859  spotify:track:6uHvbKL0Yi37AuvNRmUfMw        0,364  0,308   4,0
# 9887   spotify:track:0WWIFMlvyf3nbD7ibHxE40         0,71  0,682   9,0
# 1058   spotify:track:5KUNwkaNf8l5A9sXZhiCgI        0,728  0,832   7,0
# 6938   spotify:track:24hke0P7QZEb62QC4XzG9y        0,474  0,568   5,0
#
#       Loudness Speechiness Acousticness Instrumentalness  Liveness  Valence  \
# 13717   -5,351        0,22        0,178              0,0    0.5840    0.429
# 10389   -8,331       0,312        0,218         4,08e-05    0.1220    0.447
# 3321    -8,283      0,0498        0,586              0,0    0.0600    0.837
# 7989    -6,283      0,0385      0,00369            0,055    0.3320    0.716
# 18133  -16,192       0,155        0,673           0,0177    0.2930    0.639
# 10994   -8,552      0,0324        0,857              0,0    0.0763    0.543
# 15859  -13,052      0,0402        0,895           0,0023    0.1230    0.387
# 9887    -7,355       0,132       0,0184              0,0    0.2200    0.631
# 1058    -6,827       0,267        0,327              0,0    0.5040    0.825
# 6938    -6,068      0,0502        0,824         2,32e-06    0.2450    0.972
#
#          Tempo  Duration_ms                                  Url_youtube  \
# 13717   73.771     282353.0  https://www.youtube.com/watch?v=29UMACdfyZw
# 10389   95.015     290627.0                                          NaN
# 3321   167.016     289707.0  https://www.youtube.com/watch?v=0K20Kmw6JyY
# 7989   125.105     234227.0  https://www.youtube.com/watch?v=W3q8Od5qJio
# 18133  114.927     136696.0  https://www.youtube.com/watch?v=HC6xx-GxlUY
# 10994  109.396     184987.0  https://www.youtube.com/watch?v=QVOj-q81ydw
# 15859   73.328     191773.0  https://www.youtube.com/watch?v=PwhlS0x_7ZE
# 9887    87.018     233783.0  https://www.youtube.com/watch?v=hOk3Jv3440w
# 1058    95.051     172893.0  https://www.youtube.com/watch?v=gQtKJbptcns
# 6938   198.357     167120.0  https://www.youtube.com/watch?v=2b67hnA90RE
#
#                                                    Title             Channel  \
# 13717  MACKLEMORE & RYAN LEWIS - "Irish Celebration" ...                  SG
# 10389                                                NaN                 NaN
# 3321   Gilberto Santa Rosa - Sombra Loca (Video Version)      gsantarosaVEVO
# 7989                Rammstein - Du Hast (Official Video)  Rammstein Official
# 18133  Shiloh Dynasty & CuBox - Losing Interest (Lyrics)        Aurora Vibes
# 10994                                     Moment In Time     Cherish - Topic
# 15859                    The Paper Kites - Paint (Video)            William.
# 9887   Ras Kass GET LIT (DEDICATION) הקדשה  ft Dina R...            Ras Kass
# 1058           Rapp Snitch Knishes (feat. Mr. Fantastik)     MF DOOM - Topic
# 6938                        Banda Machos - Leña De Pirul            Freddy T
#
#              Views      Likes  Comments  \
# 13717   24643241.0   121124.0   23221.0
# 10389          NaN        NaN       NaN
# 3321    47610509.0   129218.0    2191.0
# 7989   484354563.0  2731596.0       NaN
# 18133   49040841.0  1026753.0   25034.0
# 10994    1194609.0    18719.0      80.0
# 15859      20100.0      374.0      16.0
# 9887         512.0       21.0       2.0
# 1058    17441901.0   282222.0     631.0
# 6938    15119190.0    62343.0    1059.0
#
#                                              Description Licensed  \
# 13717  PRODUCED BY - Ryan Lewis\nVIOLIN - Andrew Josl...    False
# 10389                                                NaN      NaN
# 3321   Vídeo oficial de Gilberto Santa Rosa de su tem...     True
# 7989   Order the new album: https://rammstein.lnk.to/...     True
# 18133  Discover on Spotify\nhttps://ffm.to/shilohvibe...    False
# 10994  Provided to YouTube by Universal Music Group\n...     True
# 15859                                                NaN    False
# 9887   FREE HOLIDAY DOWNLOAD https://raskass.bandcamp...     True
# 1058   Provided to YouTube by BWSCD, Inc.\n\nRapp Sni...     True
# 6938                                                        False
#
#       Official_video       Stream
# 13717          False   20320041.0
# 10389            NaN   12103359.0
# 3321            True   27269897.0
# 7989            True  403740563.0
# 18133          False   54312163.0
# 10994           True    3111137.0
# 15859          False  100447102.0
# 9887            True          NaN
# 1058            True  144822002.0
# 6938           False   25212507.0

# %% [markdown]
#         -¿Cuántas filas y columnas tenemos en el dataframe
#         -¿Cuáles son los tipos de los datos de cada columna del dataframe
#         -¿Cuántos valores nulos tenemos por columna?
#         -¿Tenemos filas duplicadas en el dataframe ?

# %%
print(f'El dataframe tiene {df1.shape[0]} filas y {df1.shape[1]} columnas')
# Out:
# El dataframe tiene 20718 filas y 27 columnas

# %%
#Con el método .dtypes podemos ver qué tipo de dato tiene cada columna

df1.dtypes
# Out:
# Artist               object
# Url_spotify          object
# Track                object
# Album                object
# Album_type           object
# Uri                  object
# Danceability         object
# Energy               object
# Key                  object
# Loudness             object
# Speechiness          object
# Acousticness         object
# Instrumentalness     object
# Liveness            float64
# Valence             float64
# Tempo               float64
# Duration_ms         float64
# Url_youtube          object
# Title                object
# Channel              object
# Views               float64
# Likes               float64
# Comments            float64
# Description          object
# Licensed             object
# Official_video       object
# Stream              float64
# dtype: object

# %%
#Podemos daber cuántos valores nulos hay en cada columna usando los métodos isnull() y sum()

df1.isnull().sum()
# Out:
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          2
# Energy                2
# Key                   2
# Loudness              2
# Speechiness           2
# Acousticness          2
# Instrumentalness      2
# Liveness              2
# Valence               2
# Tempo                 2
# Duration_ms           2
# Url_youtube         470
# Title               470
# Channel             470
# Views               470
# Likes               541
# Comments            569
# Description         876
# Licensed            470
# Official_video      470
# Stream              576
# dtype: int64

# %%
#No hay filas que estén enteramente duplicadas en este dataframe

df1.duplicated().sum()
# Out:
# 0

# %% [markdown]
#         -Muestra los principales estadísticos para las columnas numéricas del dataframe

# %%
df1.describe().T
# Out:
#                count          mean           std         min           25%  \
# Liveness     20716.0  1.935210e-01  1.685309e-01      0.0145  9.410000e-02
# Valence      20716.0  5.298533e-01  2.454408e-01      0.0000  3.390000e-01
# Tempo        20716.0  1.206383e+02  2.957902e+01      0.0000  9.700200e+01
# Duration_ms  20716.0  2.247176e+05  1.247905e+05  30985.0000  1.800095e+05
# Views        20248.0  9.393782e+07  2.746443e+08      0.0000  1.826002e+06
# Likes        20177.0  6.633411e+05  1.789324e+06      0.0000  2.158100e+04
# Comments     20149.0  2.751899e+04  1.932347e+05      0.0000  5.090000e+02
# Stream       20142.0  1.359422e+08  2.441321e+08   6574.0000  1.767486e+07
#
#                       50%           75%           max
# Liveness     1.250000e-01  2.370000e-01  1.000000e+00
# Valence      5.370000e-01  7.262500e-01  9.930000e-01
# Tempo        1.199650e+02  1.399350e+02  2.433720e+02
# Duration_ms  2.132845e+05  2.524430e+05  4.676058e+06
# Views        1.450110e+07  7.039975e+07  8.079649e+09
# Likes        1.244810e+05  5.221480e+05  5.078865e+07
# Comments     3.277000e+03  1.436000e+04  1.608314e+07
# Stream       4.968298e+07  1.383581e+08  3.386520e+09

# %% [markdown]
#         -Muestra los principales estadísticos para las columnas categóricas del dataframe

# %%
df1.describe(include = 'object').T
# Out:
#                   count unique  \
# Artist            20718   2079
# Url_spotify       20718   2079
# Track             20718  17841
# Album             20718  11937
# Album_type        20718      3
# Uri               20718  18862
# Danceability      20716    898
# Energy            20716   1268
# Key               20716     12
# Loudness          20716   9417
# Speechiness       20716   1303
# Acousticness      20716   3138
# Instrumentalness  20716   4012
# Url_youtube       20248  18154
# Title             20248  18146
# Channel           20248   6714
# Description       19842  17395
# Licensed          20248      2
# Official_video    20248      2
#
#                                                                 top   freq
# Artist                                                     Gorillaz     10
# Url_spotify       https://open.spotify.com/artist/3AA28KZvwAUcZu...     10
# Track                     El Ultimo Adiós - Varios Artistas Version     24
# Album                                                 Greatest Hits     30
# Album_type                                                    album  14926
# Uri                            spotify:track:0tzixmHNQfE6S6SirSToxW     24
# Danceability                                                  0,687     78
# Energy                                                        0,572     60
# Key                                                             0,0   2305
# Loudness                                                     -7,818     25
# Speechiness                                                  0,0324     72
# Acousticness                                                  0,114     50
# Instrumentalness                                                0,0   9391
# Url_youtube             https://www.youtube.com/watch?v=GqOvxbFLwjY     18
# Title             Color Esperanza 2020 - Various Artists (Offici...     18
# Channel                                                    T-Series    238
# Description                                                            114
# Licensed                                                       True  14140
# Official_video                                                 True  15723

# %% [markdown]
# 3.Preparación de los datos:
#
#     Los nombres de las columnas empiezan con mayúsculas, poned todos los nombres de las columnas en minúsculas.

# %%
#definimos un listado de columnas con los nombres de las columnas en minúsculas

nombres_min = {col:col.lower() for col in df1.columns}

# %%
#Cambiamos los nombres de las columnas 

df1.rename(columns = nombres_min, inplace = True) 

df1.head(2)
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#              track          album album_type  \
# 0   Feel Good Inc.     Demon Days      album
# 1  Rhinestone Eyes  Plastic Beach      album
#
#                                     uri danceability energy  key loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT        0,818  0,705  6,0   -6,679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG        0,676  0,703  8,0   -5,815
#
#   speechiness acousticness instrumentalness  liveness  valence    tempo  \
# 0       0,177      0,00836          0,00233    0.6130    0.772  138.559
# 1      0,0302       0,0869         0,000687    0.0463    0.852   92.761
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
#
#                                                title   channel        views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        likes  comments                                        description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#   licensed official_video        stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08

# %% [markdown]
#     Haciendo el análisis exploratorio nos deberíamos haber dado cuenta de que algunas de las variables (danceability, energy, key, loudness, speechiness, acousticness, instrumentalness) no son del tipo que deberían. Esto es debido a que los decimales están establecidos como comas y no con puntos. Cread una función que nos permita cambiar esas comas por puntos para que los datos tengan el tipo correcto.

# %%
registro = '0,818'
registro2 = re.sub(',', '.', registro)
registro3 = float(registro2)
type(registro3)
# Out:
# float

# %%
df1['danceability'].dtypes
# Out:
# dtype('O')

# %%
#Definimos una función para aplicarla a todos los registros de las columnas que necesitemos

def cambio(registro):
    """
        Funcion que recibe un string y lo convierte a float
        Args:
            registro(str): cada registro que tenemos en la columna del dataframe
        Returns: 
            el registro en formato float
    """
    
    if registro == str(registro):
        registro2 = re.sub(',', '.', registro)
        registro3 = float(registro2)
        return registro3
    
    else:
        return np.nan

# %%
df1['danceability'] = df1['danceability'].apply(cambio)
df1['energy'] = df1['energy'].apply(cambio)
df1['key'] = df1['key'].apply(cambio)
df1['loudness'] = df1['loudness'].apply(cambio)
df1['speechiness'] = df1['speechiness'].apply(cambio)
df1['acousticness'] = df1['acousticness'].apply(cambio)
df1['instrumentalness'] = df1['instrumentalness'].apply(cambio)
df1.head()
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            album album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# 3                                  Plastic Beach      album
# 4                                       Gorillaz      album
#
#                                     uri  danceability  energy   key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705   6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703   8.0    -5.815
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923   1.0    -3.930
# 3  spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739   2.0    -5.810
# 4  spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694  10.0    -8.627
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1770      0.008360          0.002330    0.6130    0.772  138.559
# 1       0.0302      0.086900          0.000687    0.0463    0.852   92.761
# 2       0.0522      0.042500          0.046900    0.1160    0.551  108.014
# 3       0.0260      0.000015          0.509000    0.0640    0.578  120.423
# 4       0.1710      0.025300          0.000000    0.0698    0.525  167.953
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
# 2     215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3     233867.0  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4     340920.0  https://www.youtube.com/watch?v=1V_xRb0x9aw
#
#                                                title   channel        views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
# 2  Gorillaz - New Gold ft. Tame Impala & Bootie B...  Gorillaz    8435055.0
# 3     Gorillaz - On Melancholy Hill (Official Video)  Gorillaz  211754952.0
# 4         Gorillaz - Clint Eastwood (Official Video)  Gorillaz  618480958.0
#
#        likes  comments                                        description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3  1788577.0   55229.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 4  6197318.0  155930.0  The official music video for Gorillaz - Clint ...
#
#   licensed official_video        stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08
# 2     True           True  6.306347e+07
# 3     True           True  4.346636e+08
# 4     True           True  6.172597e+08

# %% [markdown]
#         -Después de haber hecho los cambios, chequead los tipos de datos. ¿Son ya del tipo correcto? En caso de que no, cread otra función o modificar la anterior para que sean de tipo float.

# %%
#Ya son de tipo float

df1.dtypes
# Out:
# artist               object
# url_spotify          object
# track                object
# album                object
# album_type           object
# uri                  object
# danceability        float64
# energy              float64
# key                 float64
# loudness            float64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_ms         float64
# url_youtube          object
# title                object
# channel              object
# views               float64
# likes               float64
# comments            float64
# description          object
# licensed             object
# official_video       object
# stream              float64
# dtype: object

# %% [markdown]
#     Hay algunas canciones cuyo título está en mayúsulas. Crea una función para que todos los títulos estén en minúscula. Haced lo mismo para las columnas de "title" y "album".

# %%
def minusculas(registro):
    """
        Funcion que recibe un string y lo pasa a minusculas
        Args:
            registro(str): cada registro que tenemos en la columna del dataframe
        Returns: 
            el registro en minusculas
    """
    
    if registro == str(registro):
        registro2 = registro.lower()
        return registro2
    
    else:
        return np.nan

# %%
df1['track'] = df1['track'].apply(minusculas)
df1['album'] = df1['album'].apply(minusculas)
df1['title'] = df1['title'].apply(minusculas)

df1.head()
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            track  \
# 0                                 feel good inc.
# 1                                rhinestone eyes
# 2  new gold (feat. tame impala and bootie brown)
# 3                             on melancholy hill
# 4                                 clint eastwood
#
#                                            album album_type  \
# 0                                     demon days      album
# 1                                  plastic beach      album
# 2  new gold (feat. tame impala and bootie brown)     single
# 3                                  plastic beach      album
# 4                                       gorillaz      album
#
#                                     uri  danceability  energy   key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705   6.0    -6.679
# 1  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703   8.0    -5.815
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923   1.0    -3.930
# 3  spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739   2.0    -5.810
# 4  spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694  10.0    -8.627
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1770      0.008360          0.002330    0.6130    0.772  138.559
# 1       0.0302      0.086900          0.000687    0.0463    0.852   92.761
# 2       0.0522      0.042500          0.046900    0.1160    0.551  108.014
# 3       0.0260      0.000015          0.509000    0.0640    0.578  120.423
# 4       0.1710      0.025300          0.000000    0.0698    0.525  167.953
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     200173.0  https://www.youtube.com/watch?v=yYDmaexVHic
# 2     215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3     233867.0  https://www.youtube.com/watch?v=04mfKJWDSzI
# 4     340920.0  https://www.youtube.com/watch?v=1V_xRb0x9aw
#
#                                                title   channel        views  \
# 0         gorillaz - feel good inc. (official video)  Gorillaz  693555221.0
# 1  gorillaz - rhinestone eyes [storyboard film] (...  Gorillaz   72011645.0
# 2  gorillaz - new gold ft. tame impala & bootie b...  Gorillaz    8435055.0
# 3     gorillaz - on melancholy hill (official video)  Gorillaz  211754952.0
# 4         gorillaz - clint eastwood (official video)  Gorillaz  618480958.0
#
#        likes  comments                                        description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
# 2   282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3  1788577.0   55229.0  Follow Gorillaz online:\nhttp://gorillaz.com \...
# 4  6197318.0  155930.0  The official music video for Gorillaz - Clint ...
#
#   licensed official_video        stream
# 0     True           True  1.040235e+09
# 1     True           True  3.100837e+08
# 2     True           True  6.306347e+07
# 3     True           True  4.346636e+08
# 4     True           True  6.172597e+08

# %% [markdown]
#     Algunos de los artistas tienen símbolos raros, en concreto el símbolo $. Cread una función que nos elimine este símbolo de los nombres de los artistas.

# %%
def eliminar(registro):
    """
        Funcion que recibe un string y elimina el simbolo '$'
        Args:
            registro(str): cada registro que tenemos en la columna del dataframe
        Returns: 
            el registro sin el símbolo '$'
    """
    
    if registro == str(registro):
        registro2 = registro.replace('$','')
        return registro2
    
    else:
        return np.nan

# %%
df1['artist'] = df1['artist'].apply(eliminar)

# %%
df1.sample(5)
# Out:
#              artist                                        url_spotify  \
# 18939  Aya Nakamura  https://open.spotify.com/artist/7IlRNXHjoOCgEA...
# 5312         Teoman  https://open.spotify.com/artist/40KlwpvpKEQtZT...
# 10722   Dulce María  https://open.spotify.com/artist/6kaefrHSdAvxhh...
# 792     Alicia Keys  https://open.spotify.com/artist/3DiDSECUqqY1Au...
# 19960         Ajaxx  https://open.spotify.com/artist/0y7B2G0jNMGWyQ...
#
#                                             track                   album  \
# 18939                                     copines                nakamura
# 5312                    kupa kızı ve sinek valesi                     teo
# 10722                                     sálvame                 rebelde
# 792    empire state of mind (part ii) broken down  the element of freedom
# 19960                                     saturno                 saturno
#
#       album_type                                   uri  danceability  energy  \
# 18939      album  spotify:track:1Bhm5HNO1cq8olDbBmokyL         0.701   0.787
# 5312       album  spotify:track:68xnudIZzP49DreYAMlbqZ         0.586   0.773
# 10722      album  spotify:track:3hbTkJ0yFzHbawnKyhvTQj         0.473   0.657
# 792        album  spotify:track:5sra5UY6sD658OabHL3QtI         0.484   0.368
# 19960     single  spotify:track:68cPbG7hJnwDW9nPX1uQcX         0.694   0.551
#
#        key  loudness  speechiness  acousticness  instrumentalness  liveness  \
# 18939  8.0    -3.941       0.0855        0.2700          0.000000     0.105
# 5312   8.0    -5.724       0.0303        0.0187          0.000000     0.314
# 10722  6.0    -6.278       0.0240        0.0454          0.000002     0.068
# 792    6.0    -7.784       0.0341        0.7400          0.000038     0.118
# 19960  5.0    -5.929       0.0485        0.7040          0.000000     0.100
#
#        valence    tempo  duration_ms  \
# 18939    0.904  180.027     171720.0
# 5312     0.369   94.830     295067.0
# 10722    0.294   74.996     224973.0
# 792      0.142   92.923     216480.0
# 19960    0.908   95.003     186947.0
#
#                                        url_youtube  \
# 18939  https://www.youtube.com/watch?v=EkGiGf8utCM
# 5312   https://www.youtube.com/watch?v=PtsMi4dtl1o
# 10722  https://www.youtube.com/watch?v=RoayB0pLRC0
# 792    https://www.youtube.com/watch?v=a-bCVe5PR8E
# 19960                                          NaN
#
#                                                    title       channel  \
# 18939             aya nakamura - copines (clip officiel)  Aya Nakamura
# 5312   teoman - kupa kızı ve sinek valesi (official v...     MuzikPlay
# 10722                                      rbd - sálvame       RBDVEVO
# 792    alicia keys - empire state of mind (part ii) b...   Kenny Eagle
# 19960                                                NaN           NaN
#
#              views      likes  comments  \
# 18939  487021035.0  3786567.0  103602.0
# 5312    26378879.0   143774.0    7281.0
# 10722   97290294.0   957262.0   72467.0
# 792        92091.0      369.0      11.0
# 19960          NaN        NaN       NaN
#
#                                              description licensed  \
# 18939  Copines out now: 🔊 https://AyaNakamura.lnk.to/...     True
# 5312   Teoman'ın, Avrupa Müzik etiketiyle yayımlanan ...     True
# 10722  ►Escucha el álbum “Rebelde” en tu plataforma s...     True
# 792    Empire State Of Mind (Part II) Broken Down\r\n...    False
# 19960                                                NaN      NaN
#
#       official_video       stream
# 18939           True  295291971.0
# 5312            True   56301707.0
# 10722           True  156878055.0
# 792            False  335205769.0
# 19960            NaN   94950447.0

# %% [markdown]
# 4.Filtrado de datos y Visualización:
#
#     ¿Cuáles son los valores únicos de la columna "album_type"?

# %%
print(f'Los valores unicos de la columna "album_type" son:\n{df1["album_type"].value_counts()}')
# Out:
# Los valores unicos de la columna "album_type" son:
# album          14926
# single          5004
# compilation      788
# Name: album_type, dtype: int64

# %% [markdown]
#     Cread tres dataframes diferentes, uno para cada tipo de "album_type". ¿Cuántas canciones tenemos en cada tipo?

# %%
df_album = df1[df1['album_type'] == 'album']
df_single = df1[df1['album_type'] == 'single']
df_compilation = df1[df1['album_type'] == 'compilation']

# %%
print(f'Hay {df_album.shape[0]} canciones en la categoria "album"')
print('-----------------------------------')
print(f'Hay {df_single.shape[0]} canciones en la categoria "single"')
print('-----------------------------------')
print(f'Hay {df_compilation.shape[0]} canciones en la categoria "compilation"')
# Out:
# Hay 14926 canciones en la categoria "album"
# -----------------------------------
# Hay 5004 canciones en la categoria "single"
# -----------------------------------
# Hay 788 canciones en la categoria "compilation"

# %% [markdown]
#     Usando el dataframe de los albumes que hemos creado en el ejercicio anterior. ¿Cuál es la media y la desviación estándar de "danceability", "acousticness" y "speechiness" de cada artista?.

# %%
#Para calcular la media primero agrupamos por artista

print(f'La media de "danceability" de cada artista es:\n{df_album.groupby("artist")["danceability"].mean()}')
print('-----------------------------------')
print(f'La media de "acousticness" de cada artista es:\n{df_album.groupby("artist")["acousticness"].mean()}')
print('-----------------------------------')
print(f'La media de "speechiness" de cada artista es:\n{df_album.groupby("artist")["speechiness"].mean()}')
# Out:
# La media de "danceability" de cada artista es:
# artist
# (G)I-DLE             0.796500
# *NSYNC               0.622400
# 070 Shake            0.653750
# 112                  0.720250
# 11:11 Music Group    0.730000
#                        ...
# will.i.am            0.740750
# Ángela Aguilar       0.719667
# Ñejo                 0.838000
# Ñengo Flow           0.719200
# Øneheart             0.303000
# Name: danceability, Length: 1989, dtype: float64
# -----------------------------------
# La media de "acousticness" de cada artista es:
# artist
# (G)I-DLE             0.048140
# *NSYNC               0.154031
# 070 Shake            0.027217
# 112                  0.129359
# 11:11 Music Group    0.916000
#                        ...
# will.i.am            0.013537
# Ángela Aguilar       0.462000
# Ñejo                 0.177000
# Ñengo Flow           0.121820
# Øneheart             0.980000
# Name: acousticness, Length: 1989, dtype: float64
# -----------------------------------
# La media de "speechiness" de cada artista es:
# artist
# (G)I-DLE             0.128800
# *NSYNC               0.057520
# 070 Shake            0.067900
# 112                  0.139125
# 11:11 Music Group    0.034000
#                        ...
# will.i.am            0.082125
# Ángela Aguilar       0.030089
# Ñejo                 0.296000
# Ñengo Flow           0.232820
# Øneheart             0.035700
# Name: speechiness, Length: 1989, dtype: float64

# %%
print(f'La desviacion estandar de "danceability" de cada artista es:\n{df_album.groupby("artist")["danceability"].std()}')
print('-----------------------------------')
print(f'La desviacion estandar de "acousticness" de cada artista es:\n{df_album.groupby("artist")["acousticness"].std()}')
print('-----------------------------------')
print(f'La desviacion estandar de "speechiness" de cada artista es:\n{df_album.groupby("artist")["speechiness"].std()}')
# Out:
# La desviacion estandar de "danceability" de cada artista es:
# artist
# (G)I-DLE             0.058690
# *NSYNC               0.108125
# 070 Shake            0.086001
# 112                  0.097025
# 11:11 Music Group         NaN
#                        ...
# will.i.am            0.141959
# Ángela Aguilar       0.121970
# Ñejo                      NaN
# Ñengo Flow           0.102199
# Øneheart                  NaN
# Name: danceability, Length: 1989, dtype: float64
# -----------------------------------
# La desviacion estandar de "acousticness" de cada artista es:
# artist
# (G)I-DLE             0.054108
# *NSYNC               0.180663
# 070 Shake            0.027811
# 112                  0.137998
# 11:11 Music Group         NaN
#                        ...
# will.i.am            0.013039
# Ángela Aguilar       0.214559
# Ñejo                      NaN
# Ñengo Flow           0.089099
# Øneheart                  NaN
# Name: acousticness, Length: 1989, dtype: float64
# -----------------------------------
# La desviacion estandar de "speechiness" de cada artista es:
# artist
# (G)I-DLE             0.049780
# *NSYNC               0.036145
# 070 Shake            0.048658
# 112                  0.117117
# 11:11 Music Group         NaN
#                        ...
# will.i.am            0.050309
# Ángela Aguilar       0.003391
# Ñejo                      NaN
# Ñengo Flow           0.188013
# Øneheart                  NaN
# Name: speechiness, Length: 1989, dtype: float64

# %% [markdown]
#     Mostrad los resultados en tres dataframes diferentes, uno para cada métrica ("danceability", "acousticness" y "speechiness"). Ordenar los resultados de mayor a menor en base a la media.

# %%
df_media_dance = df_album.groupby("artist")["danceability"].mean().reset_index()
df_media_dance.head()
# Out:
#               artist  danceability
# 0           (G)I-DLE       0.79650
# 1             *NSYNC       0.62240
# 2          070 Shake       0.65375
# 3                112       0.72025
# 4  11:11 Music Group       0.73000

# %%
df_desv_dance = df_album.groupby("artist")["danceability"].std().reset_index()
df_desv_dance.head()
# Out:
#               artist  danceability
# 0           (G)I-DLE      0.058690
# 1             *NSYNC      0.108125
# 2          070 Shake      0.086001
# 3                112      0.097025
# 4  11:11 Music Group           NaN

# %%
#Unimos los dos dataframes en uno solo

df_dance = df_media_dance.merge(df_desv_dance, on = 'artist')
df_dance.head()
# Out:
#               artist  danceability_x  danceability_y
# 0           (G)I-DLE         0.79650        0.058690
# 1             *NSYNC         0.62240        0.108125
# 2          070 Shake         0.65375        0.086001
# 3                112         0.72025        0.097025
# 4  11:11 Music Group         0.73000             NaN

# %%
nom_col={'danceability_x':'danceability_mean', 'danceability_y':'danceability_std'}
df_dance.rename(columns = nom_col, inplace = True)
df_dance.head()
# Out:
#               artist  danceability_mean  danceability_std
# 0           (G)I-DLE            0.79650          0.058690
# 1             *NSYNC            0.62240          0.108125
# 2          070 Shake            0.65375          0.086001
# 3                112            0.72025          0.097025
# 4  11:11 Music Group            0.73000               NaN

# %%
df_media_acoust = df_album.groupby("artist")["acousticness"].mean().reset_index()

df_desv_acoust = df_album.groupby("artist")["acousticness"].std().reset_index()

df_acoust = df_media_acoust.merge(df_desv_acoust, on = 'artist')

nom_col={'acousticness_x':'acousticness_mean', 'acousticness_y':'acousticness_std'}
df_acoust.rename(columns = nom_col, inplace = True)
df_acoust.head()
# Out:
#               artist  acousticness_mean  acousticness_std
# 0           (G)I-DLE           0.048140          0.054108
# 1             *NSYNC           0.154031          0.180663
# 2          070 Shake           0.027217          0.027811
# 3                112           0.129359          0.137998
# 4  11:11 Music Group           0.916000               NaN

# %%
df_media_speech = df_album.groupby("artist")["speechiness"].mean().reset_index()

df_desv_speech = df_album.groupby("artist")["speechiness"].std().reset_index()

df_speech = df_media_speech.merge(df_desv_speech, on = 'artist')
df_dance

nom_col={'speechiness_x':'speechiness_mean', 'speechiness_y':'speechiness_std'}
df_speech.rename(columns = nom_col, inplace = True)
df_speech.head()
# Out:
#               artist  speechiness_mean  speechiness_std
# 0           (G)I-DLE          0.128800         0.049780
# 1             *NSYNC          0.057520         0.036145
# 2          070 Shake          0.067900         0.048658
# 3                112          0.139125         0.117117
# 4  11:11 Music Group          0.034000              NaN

# %% [markdown]
#     Se quiere estudiar si existe una relación entre la cantidad de visitas que reciben los videos de música de un artista en una plataforma de streaming y la cantidad de likes que estos videos obtienen.
#
#     Por lo tanto, querremos contestar a la siguiente pregunta:
#
#     ¿Son aquellos artistas que tienen más visitas los que más likes tienen?
#
#     Para solucionar este ejercicio deberéis:
#
#         -Agrupar por artista y calcular la media de visitas y de likes.
#         -Quedaros con los 10 artistas que más visitas han tenido.
#         -Quedaros con los 10 artistas que más likes han tenido.

# %%
df1.head(1)
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#             track       album album_type  \
# 0  feel good inc.  demon days      album
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.177       0.00836           0.00233     0.613    0.772  138.559
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
#
#                                         title   channel        views  \
# 0  gorillaz - feel good inc. (official video)  Gorillaz  693555221.0
#
#        likes  comments                                        description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#   licensed official_video        stream
# 0     True           True  1.040235e+09

# %%
df1.groupby('artist')['views'].mean().sort_values(ascending= False).head(10)
# Out:
# artist
# Ed Sheeran                 1.546021e+09
# CoComelon                  1.460167e+09
# Katy Perry                 1.312063e+09
# Charlie Puth               1.216759e+09
# Luis Fonsi                 1.162811e+09
# Justin Bieber              1.099106e+09
# Daddy Yankee               1.087193e+09
# Bruno Mars                 1.024092e+09
# Macklemore & Ryan Lewis    1.012206e+09
# Coldplay                   9.997278e+08
# Name: views, dtype: float64

# %%
df1.groupby('artist')['likes'].mean().sort_values(ascending= False).head(10)
# Out:
# artist
# BTS                13940380.8
# BLACKPINK          13230250.5
# Charlie Puth        8633692.5
# Ed Sheeran          8354331.9
# Justin Bieber       7858434.8
# Billie Eilish       7333853.7
# Imagine Dragons     7227447.7
# Alan Walker         6797770.2
# DJ Snake            6777583.1
# Luis Fonsi          6690848.9
# Name: likes, dtype: float64

# %% [markdown]
#         -Haced un subplot, donde en uno tengamos los 10 artistas con más likes y en el otro los 10 artistas con mas views.

# %%
df_top_views = df1.groupby('artist')['views'].mean().sort_values(ascending= False).head(10).reset_index()
df_top_views
# Out:
#                     artist         views
# 0               Ed Sheeran  1.546021e+09
# 1                CoComelon  1.460167e+09
# 2               Katy Perry  1.312063e+09
# 3             Charlie Puth  1.216759e+09
# 4               Luis Fonsi  1.162811e+09
# 5            Justin Bieber  1.099106e+09
# 6             Daddy Yankee  1.087193e+09
# 7               Bruno Mars  1.024092e+09
# 8  Macklemore & Ryan Lewis  1.012206e+09
# 9                 Coldplay  9.997278e+08

# %%
df_top_likes = df1.groupby('artist')['likes'].mean().sort_values(ascending= False).head(10).reset_index()
df_top_likes
# Out:
#             artist       likes
# 0              BTS  13940380.8
# 1        BLACKPINK  13230250.5
# 2     Charlie Puth   8633692.5
# 3       Ed Sheeran   8354331.9
# 4    Justin Bieber   7858434.8
# 5    Billie Eilish   7333853.7
# 6  Imagine Dragons   7227447.7
# 7      Alan Walker   6797770.2
# 8         DJ Snake   6777583.1
# 9       Luis Fonsi   6690848.9

# %% [markdown]
#         -BONUS Haced lo mismo para los datos de tipo "single".

# %% [markdown]
#     Ahora queremos analizar la colaboración entre artistas en la industria musical, se tienen datos de las colaboraciones realizadas en los últimos años.
#
#     Se desea conocer cuáles son los artistas que han colaborado en mayor cantidad de canciones y generar un ranking con los diez primeros.
#
#     ¿Qué artistas con los que más colaboraciones tienen?
#
#     Para esto tendréis que:
#
#         -Filtrad los datos para quedaros solo con aquellos datos donde en la columna "track" tengamos "feat".

# %%
df_feat = df1[df1['track'].str.contains('feat')]
df_feat.head(2)
# Out:
#      artist                                        url_spotify  \
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 6  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                                track  \
# 2      new gold (feat. tame impala and bootie brown)
# 6  new gold (feat. tame impala and bootie brown) ...
#
#                                                album album_type  \
# 2      new gold (feat. tame impala and bootie brown)     single
# 6  new gold (feat. tame impala and bootie brown) ...     single
#
#                                     uri  danceability  energy  key  loudness  \
# 2  spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923  1.0    -3.930
# 6  spotify:track:2c3KCGq6UojB2c8UAFrRON         0.716   0.897  4.0    -7.185
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 2       0.0522        0.0425            0.0469     0.116    0.551  108.014
# 6       0.0629        0.0120            0.2620     0.325    0.358  127.030
#
#    duration_ms                                  url_youtube  \
# 2     215150.0  https://www.youtube.com/watch?v=qJa-VFwPpYA
# 6     274142.0  https://www.youtube.com/watch?v=BONNm0F7Tto
#
#                                                title    channel      views  \
# 2  gorillaz - new gold ft. tame impala & bootie b...   Gorillaz  8435055.0
# 6  gorillaz - new gold ft. tame impala, bootie br...  Dom Dolla   451996.0
#
#       likes  comments                                        description  \
# 2  282142.0    7399.0  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 6   11686.0     241.0  Gorillaz 'New Gold' ft. Tame Impala, Bootie Br...
#
#   licensed official_video      stream
# 2     True           True  63063467.0
# 6    False           True  10666154.0

# %% [markdown]
#         -Contad cuantas canciones tiene cada artista utilizando el dataframe generado en el paso anterior.

# %%
df_top_feat = df_feat.groupby('artist')['track'].count().sort_values(ascending= False).head(10).reset_index()
df_top_feat
# Out:
#                     artist  track
# 0            Bibi und Tina     10
# 1                  Juicy J     10
# 2               Macklemore     10
# 3             Ty Dolla ign      9
# 4                DJ Khaled      9
# 5             Wu-Tang Clan      9
# 6                    B.o.B      8
# 7  Macklemore & Ryan Lewis      8
# 8             Clean Bandit      8
# 9                   Wizkid      8

# %% [markdown]
#         -Mostrad los resultados en una gráfica, seleccionado los 10 artistas con más colaboraciones.

# %%
plt.figure(figsize = (20,5))

plt.bar(df_top_feat["artist"],df_top_feat["track"])

plt.xlabel("Artista")

plt.ylabel("Total colaboraciones")

plt.title(label = 'Top 10 Colaboraciones')

plt.show()

# %% [markdown]
#         -Deberéis contestar a las siguientes preguntas:
#
#             .¿Cuáles son los diez artistas que más han colaborado según los datos que tenemos?

# %%
print(f'Los 10 artistas que más colaboraciones han hecho han sido:\n{df_top_feat["artist"].unique()}')
# Out:
# Los 10 artistas que más colaboraciones han hecho han sido:
# ['Bibi und Tina' 'Juicy J' 'Macklemore' 'Ty Dolla ign' 'DJ Khaled'
#  'Wu-Tang Clan' 'B.o.B' 'Macklemore & Ryan Lewis' 'Clean Bandit' 'Wizkid']

# %% [markdown]
#             .¿Cuál es el número de canciones en los que ha colaborado el artista que ocupa el primer lugar en el ranking?

# %%
print(f'El mayor numero de colaboraciones ha sido {df_top_feat["track"].max()}')
# Out:
# El mayor numero de colaboraciones ha sido 10

# %% [markdown]
#             .¿Cuál es el artista que ocupa el décimo lugar en el ranking y en cuántas canciones ha colaborado?

# %%
print(f'El artista que ocupa el décimo lugar en el top 10 es {df_top_feat["artist"][df_top_feat["track"].min()]} y ha colaborado {df_top_feat["track"].min()} veces')
# Out:
# El artista que ocupa el décimo lugar en el top 10 es Clean Bandit y ha colaborado 8 veces

# %%
df1.head(1)
# Out:
#      artist                                        url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#             track       album album_type  \
# 0  feel good inc.  demon days      album
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0    -6.679
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0        0.177       0.00836           0.00233     0.613    0.772  138.559
#
#    duration_ms                                  url_youtube  \
# 0     222640.0  https://www.youtube.com/watch?v=HyHNuVaZJ-k
#
#                                         title   channel        views  \
# 0  gorillaz - feel good inc. (official video)  Gorillaz  693555221.0
#
#        likes  comments                                        description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#   licensed official_video        stream
# 0     True           True  1.040235e+09

# %% [markdown]
#     Utilizando el dataframe original, queremos explorar si el tipo de álbum influye en la cantidad de vistas que recibe en una plataforma de transmisión de música.
#
#     Para ello, debemos generar un boxplot con las variables necesarias y responder las siguientes preguntas:
#
#         -¿Qué tipo de álbumes tienden a tener más vistas en promedio?

# %%
plt.figure(figsize =(8,4))

fig = sns.boxplot( x ='album_type', y = 'views', data = df1)

fig.set(xlabel='Tipo album', ylabel= 'Visitas')

fig.set_title('Numero de visitas por tipo de album')

plt.show()

# %% [markdown]
#         -¿Hay algún tipo de álbumes que tenga una mayor dispersión en las vistas recibidas?

# %%
plt.figure(figsize =(8,4))

fig = sns.swarmplot(x='album_type', y = 'views', data = df1)

fig.set(xlabel='Tipo album', ylabel= 'Visitas' )

fig.set_title('Numero de visitas por tipo de album')

plt.show()

# %% [markdown]
#         -Existen valores atípicos (outliers) en alguna categoría de álbumes?

# %% [markdown]
#         -¿Qué conclusión se puede obtener sobre la relación entre el tipo de álbum y la cantidad de vistas recibidas?
